# %% [markdown]
# # Variablen und elementare Datentypen

# %% [markdown]
# ## Zahlen

# %%
a = 2
b = 1/3
c = 1.1

d = a + b; print( d )
d = a - b; print( d )
d = a * b; print( d )
d = a / b; print( d )
# Out:
# 2.3333333333333335
# 1.6666666666666667
# 0.6666666666666666
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-911ecb115451> in <module>()
#       6 d = a - b; print( d )
#       7 d = a * b; print( d )
# ----> 8 d = a / 0; print( d )
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Strings (Zeichenketten)

# %%
vorname = "Hans"
nachname = "Huber"
print( type(nachname) )

print( f"Sehr geehrter Herr {nachname},")
# Out:
# <class 'str'>
# Sehr geehrter Herr Huber,

# %% [markdown]
# ## Logischer Datentyp (boolean)

# %%
b1 = False
b2 = True
print( b1 and b2  )

b3 = 1 < 1
print( b3 )
# Out:
# False
# False

# %% [markdown]
# # Arrays (komplex)

# %%
feature_vec = [7.2, 3.6, 6.1, 2.5]
print(feature_vec)
print( len( feature_vec ))

print( feature_vec[1] )
# Out:
# [7.2, 3.6, 6.1, 2.5]
# 4
# 3.6

# %% [markdown]
# # Operator

# %% [markdown]
# ## Equal

# %%
a = 7
b = 7
e = ( a == b )
print( e )
# Out:
# True
